# %% [markdown]
# # Description
# Greetings, this kernel provides fast.ai starter code for Bengali.AI Handwritten Grapheme Classification competition.
#
# The task proposed in this competition is recognition of handwritten Bengali letters. In contrast to similar competitions such as [mnist digit recognition](https://www.kaggle.com/c/digit-recognizer) or the recent [Kannada MNIST](https://www.kaggle.com/c/Kannada-MNIST), Bengali alphabet is quite complex and may include ~13,000 different grapheme variations. Fortunately, each grapheme can be decomposed into 3 parts: grapheme_root, vowel_diacritic, and consonant_diacritic (168, 11, and 7 independent classes, respectively). Therefore, the task of grapheme recognition is significantly simplified in comparison with 13k-way classification. Though, additional consideration may be required for this multitask classification, like checking if 3 independent models, or a single model one head, or a single model with 3 heads (this kernel) works the best. This kernel is mostly based on [my findings](https://www.kaggle.com/c/Kannada-MNIST/discussion/122430) in a recent Kannada MNIST toy competition.
#
# In addition to this kernel I have prepared a [code](https://www.kaggle.com/iafoss/image-preprocessing-128x128) for data preprocessing and generation of cropped images rescaled to 128x128. Because the data has much higher resolution than MNIST or CIFAR, the things that work there may be less applicable to this data, while ImageNet based solutions should be more suitable. So, I've choosen DenseNet121 as a starter network. In addition to this kernel I will prepare a submission kernel posted separately.

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

import fastai
from fastai.vision import *
from fastai.callbacks import SaveModelCallback
import os
from sklearn.model_selection import KFold
from radam import *
# from csvlogger import *
# from mish_activation import *
import warnings
warnings.filterwarnings("ignore")

fastai.__version__
# Out:
# '1.0.59'

# %%
#change sz and bs accordingly
sz = 256
bs = 16
nfolds = 4 #keep the same split as the initial dataset
fold = 2
SEED = 2019
TRAIN = '../input/grapheme-imgs-128x128/'
LABELS = '../input/bengaliai-cv19/train.csv'
arch = models.densenet201

def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

seed_everything(SEED)

# %% [markdown]
# # Data

# %%
df = pd.read_csv(LABELS)
nunique = list(df.nunique())[1:-1]
print(nunique)
df.head()
# Out:
# [168, 11, 7]
#   image_id  grapheme_root  vowel_diacritic  consonant_diacritic grapheme
# 0  Train_0             15                9                    5   ক্ট্রো
# 1  Train_1            159                0                    0        হ
# 2  Train_2             22                3                    5     খ্রী
# 3  Train_3             53                2                    2     র্টি
# 4  Train_4             71                9                    5     থ্রো

# %%
stats = ([0.0692], [0.2051])
data = (ImageList.from_df(df, path='.', folder=TRAIN, suffix='.png', 
        cols='image_id', convert_mode='L')
        .split_by_idx(range(fold*len(df)//nfolds,(fold+1)*len(df)//nfolds))
        .label_from_df(cols=['grapheme_root','vowel_diacritic','consonant_diacritic'])
        .transform(get_transforms(do_flip=False,max_warp=0.1), size=sz, padding_mode='zeros')
        .databunch(bs=bs)).normalize(stats)

data.show_batch()

# %% [markdown]
# # Model

# %% [markdown]
# The starter model is based on DenseNet121, which I found to work quite well for such kind of problems. The first conv is replaced to accommodate for 1 channel input, and the corresponding pretrained weights are summed. ReLU activation is replaced by Mish, which works noticeably better for all tasks I checked it so far. Since each portion of the prediction (grapheme_root, vowel_diacritic, and consonant_diacritic) is quite independent concept, I create a separate head for each of them (though I didn't do a comparison with one head solution).

# %%
class Mish(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, x):
        #inlining this saves 1 second per epoch (V100 GPU) vs having a temp x and then returning x(!)
        return x *( torch.tanh(F.softplus(x)))

# %%
def to_Mish(layers):
    for i in range(len(layers)):
        layer = layers[i]
        if isinstance(layer, nn.ReLU):
            layers[i] = Mish()

# %%
# !pip install efficientnet_pytorch

from efficientnet_pytorch import EfficientNet
from efficientnet_pytorch.utils import *
# Out:
# Collecting efficientnet_pytorch
#   Downloading https://files.pythonhosted.org/packages/b8/cb/0309a6e3d404862ae4bc017f89645cf150ac94c14c88ef81d215c8e52925/efficientnet_pytorch-0.6.3.tar.gz
# Requirement already satisfied: torch in /opt/conda/lib/python3.6/site-packages (from efficientnet_pytorch) (1.3.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.6/site-packages (from torch->efficientnet_pytorch) (1.17.4)
# Building wheels for collected packages: efficientnet-pytorch
# done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.6.3-cp36-none-any.whl size=12419 sha256=f213aa3df449e00d12cf74c0ab235223c60d3e03378dfb82774e9a90481fba77
#   Stored in directory: /root/.cache/pip/wheels/42/1e/a9/2a578ba9ad04e776e80bf0f70d8a7f4c29ec0718b92d8f6ccd
# Successfully built efficientnet-pytorch
# Installing collected packages: efficientnet-pytorch
# Successfully installed efficientnet-pytorch-0.6.3

# %%
class SELayer(nn.Module):
    def __init__(self, channel, reduction=16):
        super(SELayer, self).__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.fc = nn.Sequential(
            nn.Linear(channel, channel // reduction, bias=False),
            nn.ReLU(inplace=True),
            nn.Linear(channel // reduction, channel, bias=False),
            nn.Sigmoid()
        )

    def forward(self, x):
        b, c, _, _ = x.size()
        y = self.avg_pool(x).view(b, c)
        y = self.fc(y).view(b, c, 1, 1)
        return x * y.expand_as(x)

class Head(nn.Module):
    def __init__(self, nc, n, ps=0.5):
        super().__init__()
        layers = [AdaptiveConcatPool2d(), SELayer(nc*2), Mish(), Flatten()] + \
            bn_drop_lin(nc*2, 512, True, ps, nn.ReLU(inplace=True)) + \
            bn_drop_lin(512, n, True, ps)
        self.fc = nn.Sequential(*layers)
        to_Mish(self.fc)
        self._init_weight()
        
    def _init_weight(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                torch.nn.init.kaiming_normal_(m.weight)
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1.0)
                m.bias.data.zero_()
        
    def forward(self, x):
        return self.fc(x)
    
class EfficientNet_1Channel(nn.Module):
    def __init__(self, arch=arch, n=nunique, pre=True, ps=0.5):
        super().__init__()
        
        model = EfficientNet.from_pretrained('efficientnet-b7')


        _conv_stem = Conv2dStaticSamePadding(1, 48, kernel_size=(3, 3), stride=(2, 2), bias=False, image_size=[600,600])
        w = (model._conv_stem.weight.sum(1)).unsqueeze(1)
        _conv_stem.weight = nn.Parameter(w)

        self.layer0 = nn.Sequential(_conv_stem, model._bn0)
        self.layer1 = nn.Sequential(*model._blocks[0:])
        self.layer2 = nn.Sequential(model._conv_head)
        self.layer3 = nn.Sequential(nn.BatchNorm2d(2560, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True),
                                    nn.AdaptiveAvgPool2d(output_size=1),
                                    nn.Dropout(p=0.5, inplace=False))

        # nc = self.layer3[-1].weight.shape[0]
#         self.head1 = Head(2560,n[0])
        self.head2 = Head(2560,n[1])
        self.head3 = Head(2560,n[2])
        
        self.auxhead1 = Head(2578,n[0])
#         self.auxhead2 = Head(2735,n[1])
#         self.auxhead3 = Head(2739,n[2])
        
        to_Mish(self.layer0), to_Mish(self.layer1), to_Mish(self.layer2)
        to_Mish(self.layer3)
        
    def forward(self, x):    
        #x =  F.interpolate(x, scale_factor=2, mode='bilinear')
        x = self.layer0(x)
        x = self.layer1(x)
        x = self.layer2(x)
        x = self.layer3(x)
        
#         x1 = self.head1(x)
        x2 = self.head2(x)
        x3 = self.head3(x)
        
        aux_x2 = x2.view(x2.shape[0], 11, 1, 1)
        aux_x3 = x3.view(x3.shape[0], 7, 1, 1)
        
        aux_x1 = torch.cat((x, aux_x2, aux_x3), 1)
#         aux_x2 = torch.cat((x, aux_x1, aux_x3), 1)
#         aux_x3 = torch.cat((x, aux_x1, aux_x2), 1)
        
        aux_x1 = self.auxhead1(aux_x1)
#         aux_x2 = self.auxhead2(aux_x2)
#         aux_x3 = self.auxhead3(aux_x3)

#         return x1,x2,x3
        return aux_x1,x2,x3

# %% [markdown]
# # Loss

# %% [markdown]
# Cross entropy loss is applied independently to each part of the prediction and the result is summed with the corresponding weight.

# %%
class FocalLoss(nn.Module):
    def __init__(self, alpha=1., gamma=2.):
        super().__init__()
        self.alpha = alpha
        self.gamma = gamma

    def forward(self, inputs, targets, reduction, **kwargs):
        CE_loss = F.cross_entropy(inputs,targets,reduction=reduction)
        pt = torch.exp(-CE_loss)
        F_loss = self.alpha * ((1-pt)**self.gamma) * CE_loss
        return F_loss.mean()
    

def lin_comb(v1, v2, beta): return beta*v1 + (1-beta)*v2
    
def reduce_loss(loss, reduction='mean'):
    return loss.mean() if reduction=='mean' else loss.sum() if reduction=='sum' else loss
    
class LabelSmoothingCrossEntropy(nn.Module):
    def __init__(self, ε:float=0.1, reduction='mean'):
        super().__init__()
        self.ε,self.reduction = ε,reduction
        
    def forward(self, output, target):
        c = output.size()[-1]
        log_preds = F.log_softmax(output, dim=-1)
        loss = reduce_loss(-log_preds.sum(dim=-1), self.reduction)
        nll = F.nll_loss(log_preds, target, reduction=self.reduction)
        return lin_comb(loss/c, nll, self.ε)
    
focal_loss = FocalLoss()
ls_cee = LabelSmoothingCrossEntropy()

class Loss_combine(nn.Module):
    def __init__(self):
        super().__init__()
        
    def forward(self, input, target,reduction='mean'):
        aux_x1, x2, x3 = input
        aux_x1, x2, x3 = aux_x1.float(),x2.float(),x3.float()
#         x1, x2, x3 = input
#         x1, x2, x3 = x1.float(),x2.float(),x3.float()
        y = target.long()
    
        # standard
        return 0.5*F.cross_entropy(aux_x1,y[:,0],reduction=reduction) + \
               0.25*F.cross_entropy(x2,y[:,1],reduction=reduction) + \
               0.25*F.cross_entropy(x3,y[:,2],reduction=reduction) 
    
#         return 0.5*focal_loss(aux_x1, y[:,0], reduction=reduction) + \
#                0.25*focal_loss(x2, y[:,1], reduction=reduction) + \
#                0.25*focal_loss(x3, y[:,2], reduction=reduction)
        
        # label smoothing
#         return 0.5*ls_cee(aux_x1, y[:,0]) + 0.25*ls_cee(x2, y[:,1]) + 0.25*ls_cee(x3, y[:,2])
        
        # weighted
#         return 0.7*F.cross_entropy(aux_x1,y[:,0],reduction=reduction) + \
#                0.15*F.cross_entropy(x2,y[:,1],reduction=reduction) + \
#                0.15*F.cross_entropy(x3,y[:,2],reduction=reduction)

# %% [markdown]
# The code below computes the competition metric and recall macro metrics for individual components of the prediction. The code is partially borrowed from fast.ai.

# %%
from fastai.callbacks import *

class Metric_idx(Callback):
    def __init__(self, idx, average='macro'):
        super().__init__()
        self.idx = idx
        self.n_classes = 0
        self.average = average
        self.cm = None
        self.eps = 1e-9
        
    def on_epoch_begin(self, **kwargs):
        self.tp = 0
        self.fp = 0
        self.cm = None
    
    def on_batch_end(self, last_output:Tensor, last_target:Tensor, **kwargs):
        last_output = last_output[self.idx]
        last_target = last_target[:,self.idx]
        preds = last_output.argmax(-1).view(-1).cpu()
        targs = last_target.long().cpu()
        
        if self.n_classes == 0:
            self.n_classes = last_output.shape[-1]
            self.x = torch.arange(0, self.n_classes)
        cm = ((preds==self.x[:, None]) & (targs==self.x[:, None, None])) \
          .sum(dim=2, dtype=torch.float32)
        if self.cm is None: self.cm =  cm
        else:               self.cm += cm

    def _weights(self, avg:str):
        if self.n_classes != 2 and avg == "binary":
            avg = self.average = "macro"
            warn("average=`binary` was selected for a non binary case. \
                 Value for average has now been set to `macro` instead.")
        if avg == "binary":
            if self.pos_label not in (0, 1):
                self.pos_label = 1
                warn("Invalid value for pos_label. It has now been set to 1.")
            if self.pos_label == 1: return Tensor([0,1])
            else: return Tensor([1,0])
        elif avg == "micro": return self.cm.sum(dim=0) / self.cm.sum()
        elif avg == "macro": return torch.ones((self.n_classes,)) / self.n_classes
        elif avg == "weighted": return self.cm.sum(dim=1) / self.cm.sum()
        
    def _recall(self):
        rec = torch.diag(self.cm) / (self.cm.sum(dim=1) + self.eps)
        if self.average is None: return rec
        else:
            if self.average == "micro": weights = self._weights(avg="weighted")
            else: weights = self._weights(avg=self.average)
            return (rec * weights).sum()
    
    def on_epoch_end(self, last_metrics, **kwargs): 
        return add_metrics(last_metrics, self._recall())
    
Metric_grapheme = partial(Metric_idx,0)
Metric_vowel = partial(Metric_idx,1)
Metric_consonant = partial(Metric_idx,2)

# Metric_aux_grapheme = partial(Metric_idx,3)
# Metric_aux_vowel = partial(Metric_idx,4)
# Metric_aux_consonant = partial(Metric_idx,5)

class Metric_tot(Callback):
    def __init__(self):
        super().__init__()
        self.grapheme = Metric_idx(0)
        self.vowel = Metric_idx(1)
        self.consonant = Metric_idx(2)
#         self.aux_grapheme = Metric_idx(3)
#         self.aux_vowel = Metric_idx(4)
#         self.aux_consonant = Metric_idx(5)
        
    def on_epoch_begin(self, **kwargs):
        self.grapheme.on_epoch_begin(**kwargs)
        self.vowel.on_epoch_begin(**kwargs)
        self.consonant.on_epoch_begin(**kwargs)
#         self.aux_grapheme.on_epoch_begin(**kwargs)
#         self.aux_vowel.on_epoch_begin(**kwargs)
#         self.aux_consonant.on_epoch_begin(**kwargs)
    
    def on_batch_end(self, last_output:Tensor, last_target:Tensor, **kwargs):
        self.grapheme.on_batch_end(last_output, last_target, **kwargs)
        self.vowel.on_batch_end(last_output, last_target, **kwargs)
        self.consonant.on_batch_end(last_output, last_target, **kwargs)
        
#         self.aux_grapheme.on_batch_end(last_output, last_target, **kwargs)
#         self.aux_vowel.on_batch_end(last_output, last_target, **kwargs)
#         self.aux_consonant.on_batch_end(last_output, last_target, **kwargs)
        
    def on_epoch_end(self, last_metrics, **kwargs): 
        return add_metrics(last_metrics, 0.5*self.grapheme._recall() +
                0.25*self.vowel._recall() + 0.25*self.consonant._recall())

# %%
#fix the issue in fast.ai of saving gradients along with weights
#so only weights are written, and files are ~4 times smaller

from fastai.callbacks import *

class SaveModelCallback(TrackerCallback):
    "A `TrackerCallback` that saves the model when monitored quantity is best."
    def __init__(self, learn:Learner, monitor:str='valid_loss', mode:str='auto',
                 every:str='improvement', name:str='bestmodel'):
        super().__init__(learn, monitor=monitor, mode=mode)
        self.every,self.name = every,name
        if self.every not in ['improvement', 'epoch']:
            warn(f'SaveModel every {self.every} is invalid, falling back to "improvement".')
            self.every = 'improvement'
                 
    def jump_to_epoch(self, epoch:int)->None:
        try: 
            self.learn.load(f'{self.name}_{epoch-1}', purge=False)
            print(f"Loaded {self.name}_{epoch-1}")
        except: print(f'Model {self.name}_{epoch-1} not found.')

    def on_epoch_end(self, epoch:int, **kwargs:Any)->None:
        "Compare the value monitored to its best score and maybe save the model."
        if self.every=="epoch": 
            #self.learn.save(f'{self.name}_{epoch}')
            torch.save(learn.model.state_dict(),f'{self.name}_{epoch}.pth')
        else: #every="improvement"
            current = self.get_monitor_value()
            if current is not None and self.operator(current, self.best):
                #print(f'Better model found at epoch {epoch} \
                #  with {self.monitor} value: {current}.')
                self.best = current
                #self.learn.save(f'{self.name}')
                torch.save(learn.model.state_dict(),f'{self.name}.pth')

    def on_train_end(self, **kwargs):
        "Load the best model."
        if self.every=="improvement" and os.path.isfile(f'{self.name}.pth'):
            #self.learn.load(f'{self.name}', purge=False)
            self.model.load_state_dict(torch.load(f'{self.name}.pth'))

# %%
class MixUpLoss(Module):
    "Adapt the loss function `crit` to go with mixup."
    
    def __init__(self, crit, reduction='mean'):
        super().__init__()
        if hasattr(crit, 'reduction'): 
            self.crit = crit
            self.old_red = crit.reduction
            setattr(self.crit, 'reduction', 'none')
        else: 
            self.crit = partial(crit, reduction='none')
            self.old_crit = crit
        self.reduction = reduction
        
    def forward(self, output, target):
        if len(target.shape) == 2 and target.shape[1] == 7:
            loss1, loss2 = self.crit(output,target[:,0:3].long()), self.crit(output,target[:,3:6].long())
            d = loss1 * target[:,-1] + loss2 * (1-target[:,-1])
        else:  d = self.crit(output, target)
        if self.reduction == 'mean':    return d.mean()
        elif self.reduction == 'sum':   return d.sum()
        return d
    
    def get_old(self):
        if hasattr(self, 'old_crit'):  return self.old_crit
        elif hasattr(self, 'old_red'): 
            setattr(self.crit, 'reduction', self.old_red)
            return self.crit

class MixUpCallback(LearnerCallback):
    "Callback that creates the mixed-up input and target."
    def __init__(self, learn:Learner, alpha:float=0.4, stack_x:bool=False, stack_y:bool=True):
        super().__init__(learn)
        self.alpha,self.stack_x,self.stack_y = alpha,stack_x,stack_y
    
    def on_train_begin(self, **kwargs):
        if self.stack_y: self.learn.loss_func = MixUpLoss(self.learn.loss_func)
        
    def on_batch_begin(self, last_input, last_target, train, **kwargs):
        "Applies mixup to `last_input` and `last_target` if `train`."
        if not train: return
        lambd = np.random.beta(self.alpha, self.alpha, last_target.size(0))
        lambd = np.concatenate([lambd[:,None], 1-lambd[:,None]], 1).max(1)
        lambd = last_input.new(lambd)
        shuffle = torch.randperm(last_target.size(0)).to(last_input.device)
        x1, y1 = last_input[shuffle], last_target[shuffle]
        if self.stack_x:
            new_input = [last_input, last_input[shuffle], lambd]
        else: 
            out_shape = [lambd.size(0)] + [1 for _ in range(len(x1.shape) - 1)]
            new_input = (last_input * lambd.view(out_shape) + x1 * (1-lambd).view(out_shape))
        if self.stack_y:
            new_target = torch.cat([last_target.float(), y1.float(), lambd[:,None].float()], 1)
        else:
            if len(last_target.shape) == 2:
                lambd = lambd.unsqueeze(1).float()
            new_target = last_target.float() * lambd + y1.float() * (1-lambd)
        return {'last_input': new_input, 'last_target': new_target}  
    
    def on_train_end(self, **kwargs):
        if self.stack_y: self.learn.loss_func = self.learn.loss_func.get_old()

# %% [markdown]
# # Training

# %% [markdown]
# I have performed a check of different optimizers and schedules on a [similar task](https://www.kaggle.com/c/Kannada-MNIST/discussion/122430), and [Over9000 optimizer](https://github.com/mgrankin/over9000) cosine annealing **without warm-up** worked the best. Freezing the backbone at the initial stage of training didn't give me any advantage in that test, so here I perform the training straight a way with discriminative learning rate (smaller lr for backbone).

# %%
# model = Dnet_1ch()
model = EfficientNet_1Channel()
learn = Learner(data, model, loss_func=Loss_combine(), opt_func=Over9000,
        metrics=[Metric_grapheme(),Metric_vowel(),Metric_consonant(),Metric_tot()])
logger = CSVLogger(learn,f'log{fold}')
learn.clip_grad = 1.0
learn.split([model.auxhead1])
learn.unfreeze()
# Out:
# Downloading: "https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b7-dcc49843.pth" to /root/.cache/torch/checkpoints/efficientnet-b7-dcc49843.pth
# 100%|██████████| 254M/254M [00:06<00:00, 39.9MB/s]
# Loaded pretrained weights for efficientnet-b7

# %%
MODEL = '/kaggle/input/128fold2/model_2'
learn.load(MODEL)
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (150630 items)
# x: ImageList
# Image (1, 256, 256),Image (1, 256, 256),Image (1, 256, 256),Image (1, 256, 256),Image (1, 256, 256)
# y: MultiCategoryList
# ,,,,
# Path: .;
#
# Valid: LabelList (50210 items)
# x: ImageList
# Image (1, 256, 256),Image (1, 256, 256),Image (1, 256, 256),Image (1, 256, 256),Image (1, 256, 256)
# y: MultiCategoryList
# ,vowel_diacritic,,,
# Path: .;
#
# Test: None, model=EfficientNet_1Channel(
#   (layer0): Sequential(
#     (0): Conv2dStaticSamePadding(
#       1, 48, kernel_size=(3, 3), stride=(2, 2), bias=False
#       (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#     )
#     (1): BatchNorm2d(64, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   )
#   (layer1): Sequential(
#     (0): MBConvBlock(
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         64, 64, kernel_size=(3, 3), stride=[1, 1], groups=64, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(64, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         64, 16, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         16, 64, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (1): MBConvBlock(
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         32, 32, kernel_size=(3, 3), stride=(1, 1), groups=32, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         32, 8, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         8, 32, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (2): MBConvBlock(
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         32, 32, kernel_size=(3, 3), stride=(1, 1), groups=32, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         32, 8, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         8, 32, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (3): MBConvBlock(
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         32, 32, kernel_size=(3, 3), stride=(1, 1), groups=32, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         32, 8, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         8, 32, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (4): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         192, 192, kernel_size=(3, 3), stride=[2, 2], groups=192, bias=False
#         (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         192, 8, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         8, 192, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (5): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         288, 288, kernel_size=(3, 3), stride=(1, 1), groups=288, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         288, 12, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         12, 288, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (6): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         288, 288, kernel_size=(3, 3), stride=(1, 1), groups=288, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         288, 12, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         12, 288, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (7): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         288, 288, kernel_size=(3, 3), stride=(1, 1), groups=288, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         288, 12, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         12, 288, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (8): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         288, 288, kernel_size=(3, 3), stride=(1, 1), groups=288, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         288, 12, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         12, 288, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (9): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         288, 288, kernel_size=(3, 3), stride=(1, 1), groups=288, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         288, 12, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         12, 288, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (10): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         288, 288, kernel_size=(3, 3), stride=(1, 1), groups=288, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         288, 12, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         12, 288, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (11): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         288, 288, kernel_size=(5, 5), stride=[2, 2], groups=288, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         288, 12, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         12, 288, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         288, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (12): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         480, 480, kernel_size=(5, 5), stride=(1, 1), groups=480, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         480, 20, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         20, 480, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (13): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         480, 480, kernel_size=(5, 5), stride=(1, 1), groups=480, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         480, 20, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         20, 480, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (14): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         480, 480, kernel_size=(5, 5), stride=(1, 1), groups=480, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         480, 20, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         20, 480, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (15): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         480, 480, kernel_size=(5, 5), stride=(1, 1), groups=480, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         480, 20, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         20, 480, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (16): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         480, 480, kernel_size=(5, 5), stride=(1, 1), groups=480, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         480, 20, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         20, 480, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (17): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         480, 480, kernel_size=(5, 5), stride=(1, 1), groups=480, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         480, 20, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         20, 480, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (18): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         480, 480, kernel_size=(3, 3), stride=[2, 2], groups=480, bias=False
#         (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         480, 20, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         20, 480, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         480, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (19): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(3, 3), stride=(1, 1), groups=960, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (20): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(3, 3), stride=(1, 1), groups=960, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (21): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(3, 3), stride=(1, 1), groups=960, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (22): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(3, 3), stride=(1, 1), groups=960, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (23): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(3, 3), stride=(1, 1), groups=960, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (24): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(3, 3), stride=(1, 1), groups=960, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (25): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(3, 3), stride=(1, 1), groups=960, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (26): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(3, 3), stride=(1, 1), groups=960, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (27): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(3, 3), stride=(1, 1), groups=960, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (28): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(5, 5), stride=[1, 1], groups=960, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 224, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(224, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (29): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1344, 1344, kernel_size=(5, 5), stride=(1, 1), groups=1344, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1344, 56, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         56, 1344, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(224, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (30): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1344, 1344, kernel_size=(5, 5), stride=(1, 1), groups=1344, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1344, 56, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         56, 1344, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(224, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (31): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1344, 1344, kernel_size=(5, 5), stride=(1, 1), groups=1344, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1344, 56, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         56, 1344, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(224, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (32): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1344, 1344, kernel_size=(5, 5), stride=(1, 1), groups=1344, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1344, 56, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         56, 1344, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(224, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (33): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1344, 1344, kernel_size=(5, 5), stride=(1, 1), groups=1344, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1344, 56, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         56, 1344, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(224, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (34): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1344, 1344, kernel_size=(5, 5), stride=(1, 1), groups=1344, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1344, 56, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         56, 1344, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(224, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (35): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1344, 1344, kernel_size=(5, 5), stride=(1, 1), groups=1344, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1344, 56, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         56, 1344, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(224, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (36): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1344, 1344, kernel_size=(5, 5), stride=(1, 1), groups=1344, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1344, 56, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         56, 1344, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(224, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (37): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1344, 1344, kernel_size=(5, 5), stride=(1, 1), groups=1344, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1344, 56, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         56, 1344, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(224, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (38): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1344, 1344, kernel_size=(5, 5), stride=[2, 2], groups=1344, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1344, 56, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         56, 1344, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1344, 384, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (39): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         2304, 2304, kernel_size=(5, 5), stride=(1, 1), groups=2304, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         2304, 96, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         96, 2304, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (40): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
# ...
#   (551): Identity()
#   (552): ParameterModule()
#   (553): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (554): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (555): ParameterModule()
#   (556): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (557): Identity()
#   (558): ParameterModule()
#   (559): ParameterModule()
#   (560): Identity()
#   (561): ParameterModule()
#   (562): ParameterModule()
#   (563): Identity()
#   (564): ParameterModule()
#   (565): BatchNorm2d(224, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (566): MemoryEfficientSwish()
#   (567): Identity()
#   (568): ParameterModule()
#   (569): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (570): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (571): ParameterModule()
#   (572): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (573): Identity()
#   (574): ParameterModule()
#   (575): ParameterModule()
#   (576): Identity()
#   (577): ParameterModule()
#   (578): ParameterModule()
#   (579): Identity()
#   (580): ParameterModule()
#   (581): BatchNorm2d(224, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (582): MemoryEfficientSwish()
#   (583): Identity()
#   (584): ParameterModule()
#   (585): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (586): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (587): ParameterModule()
#   (588): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (589): Identity()
#   (590): ParameterModule()
#   (591): ParameterModule()
#   (592): Identity()
#   (593): ParameterModule()
#   (594): ParameterModule()
#   (595): Identity()
#   (596): ParameterModule()
#   (597): BatchNorm2d(224, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (598): MemoryEfficientSwish()
#   (599): Identity()
#   (600): ParameterModule()
#   (601): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (602): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#   (603): ParameterModule()
#   (604): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (605): Identity()
#   (606): ParameterModule()
#   (607): ParameterModule()
#   (608): Identity()
#   (609): ParameterModule()
#   (610): ParameterModule()
#   (611): Identity()
#   (612): ParameterModule()
#   (613): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (614): MemoryEfficientSwish()
#   (615): Identity()
#   (616): ParameterModule()
#   (617): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (618): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (619): ParameterModule()
#   (620): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (621): Identity()
#   (622): ParameterModule()
#   (623): ParameterModule()
#   (624): Identity()
#   (625): ParameterModule()
#   (626): ParameterModule()
#   (627): Identity()
#   (628): ParameterModule()
#   (629): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (630): MemoryEfficientSwish()
#   (631): Identity()
#   (632): ParameterModule()
#   (633): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (634): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (635): ParameterModule()
#   (636): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (637): Identity()
#   (638): ParameterModule()
#   (639): ParameterModule()
#   (640): Identity()
#   (641): ParameterModule()
#   (642): ParameterModule()
#   (643): Identity()
#   (644): ParameterModule()
#   (645): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (646): MemoryEfficientSwish()
#   (647): Identity()
#   (648): ParameterModule()
#   (649): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (650): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (651): ParameterModule()
#   (652): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (653): Identity()
#   (654): ParameterModule()
#   (655): ParameterModule()
#   (656): Identity()
#   (657): ParameterModule()
#   (658): ParameterModule()
#   (659): Identity()
#   (660): ParameterModule()
#   (661): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (662): MemoryEfficientSwish()
#   (663): Identity()
#   (664): ParameterModule()
#   (665): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (666): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (667): ParameterModule()
#   (668): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (669): Identity()
#   (670): ParameterModule()
#   (671): ParameterModule()
#   (672): Identity()
#   (673): ParameterModule()
#   (674): ParameterModule()
#   (675): Identity()
#   (676): ParameterModule()
#   (677): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (678): MemoryEfficientSwish()
#   (679): Identity()
#   (680): ParameterModule()
#   (681): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (682): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (683): ParameterModule()
#   (684): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (685): Identity()
#   (686): ParameterModule()
#   (687): ParameterModule()
#   (688): Identity()
#   (689): ParameterModule()
#   (690): ParameterModule()
#   (691): Identity()
#   (692): ParameterModule()
#   (693): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (694): MemoryEfficientSwish()
#   (695): Identity()
#   (696): ParameterModule()
#   (697): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (698): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (699): ParameterModule()
#   (700): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (701): Identity()
#   (702): ParameterModule()
#   (703): ParameterModule()
#   (704): Identity()
#   (705): ParameterModule()
#   (706): ParameterModule()
#   (707): Identity()
#   (708): ParameterModule()
#   (709): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (710): MemoryEfficientSwish()
#   (711): Identity()
#   (712): ParameterModule()
#   (713): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (714): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (715): ParameterModule()
#   (716): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (717): Identity()
#   (718): ParameterModule()
#   (719): ParameterModule()
#   (720): Identity()
#   (721): ParameterModule()
#   (722): ParameterModule()
#   (723): Identity()
#   (724): ParameterModule()
#   (725): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (726): MemoryEfficientSwish()
#   (727): Identity()
#   (728): ParameterModule()
#   (729): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (730): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (731): ParameterModule()
#   (732): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (733): Identity()
#   (734): ParameterModule()
#   (735): ParameterModule()
#   (736): Identity()
#   (737): ParameterModule()
#   (738): ParameterModule()
#   (739): Identity()
#   (740): ParameterModule()
#   (741): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (742): MemoryEfficientSwish()
#   (743): Identity()
#   (744): ParameterModule()
#   (745): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (746): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (747): ParameterModule()
#   (748): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (749): Identity()
#   (750): ParameterModule()
#   (751): ParameterModule()
#   (752): Identity()
#   (753): ParameterModule()
#   (754): ParameterModule()
#   (755): Identity()
#   (756): ParameterModule()
#   (757): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (758): MemoryEfficientSwish()
#   (759): Identity()
#   (760): ParameterModule()
#   (761): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (762): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (763): ParameterModule()
#   (764): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (765): Identity()
#   (766): ParameterModule()
#   (767): ParameterModule()
#   (768): Identity()
#   (769): ParameterModule()
#   (770): ParameterModule()
#   (771): Identity()
#   (772): ParameterModule()
#   (773): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (774): MemoryEfficientSwish()
#   (775): Identity()
#   (776): ParameterModule()
#   (777): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (778): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (779): ParameterModule()
#   (780): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (781): Identity()
#   (782): ParameterModule()
#   (783): ParameterModule()
#   (784): Identity()
#   (785): ParameterModule()
#   (786): ParameterModule()
#   (787): Identity()
#   (788): ParameterModule()
#   (789): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (790): MemoryEfficientSwish()
#   (791): Identity()
#   (792): ParameterModule()
#   (793): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (794): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (795): ParameterModule()
#   (796): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (797): Identity()
#   (798): ParameterModule()
#   (799): ParameterModule()
#   (800): Identity()
#   (801): ParameterModule()
#   (802): ParameterModule()
#   (803): Identity()
#   (804): ParameterModule()
#   (805): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (806): MemoryEfficientSwish()
#   (807): Identity()
#   (808): ParameterModule()
#   (809): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (810): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (811): ParameterModule()
#   (812): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (813): Identity()
#   (814): ParameterModule()
#   (815): ParameterModule()
#   (816): Identity()
#   (817): ParameterModule()
#   (818): ParameterModule()
#   (819): Identity()
#   (820): ParameterModule()
#   (821): BatchNorm2d(640, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (822): MemoryEfficientSwish()
#   (823): Identity()
#   (824): ParameterModule()
#   (825): BatchNorm2d(3840, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (826): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (827): ParameterModule()
#   (828): BatchNorm2d(3840, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (829): Identity()
#   (830): ParameterModule()
#   (831): ParameterModule()
#   (832): Identity()
#   (833): ParameterModule()
#   (834): ParameterModule()
#   (835): Identity()
#   (836): ParameterModule()
#   (837): BatchNorm2d(640, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (838): MemoryEfficientSwish()
#   (839): Identity()
#   (840): ParameterModule()
#   (841): BatchNorm2d(3840, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (842): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (843): ParameterModule()
#   (844): BatchNorm2d(3840, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (845): Identity()
#   (846): ParameterModule()
#   (847): ParameterModule()
#   (848): Identity()
#   (849): ParameterModule()
#   (850): ParameterModule()
#   (851): Identity()
#   (852): ParameterModule()
#   (853): BatchNorm2d(640, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (854): MemoryEfficientSwish()
#   (855): Identity()
#   (856): ParameterModule()
#   (857): BatchNorm2d(3840, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (858): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (859): ParameterModule()
#   (860): BatchNorm2d(3840, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (861): Identity()
#   (862): ParameterModule()
#   (863): ParameterModule()
#   (864): Identity()
#   (865): ParameterModule()
#   (866): ParameterModule()
#   (867): Identity()
#   (868): ParameterModule()
#   (869): BatchNorm2d(640, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (870): MemoryEfficientSwish()
#   (871): Identity()
#   (872): ParameterModule()
#   (873): BatchNorm2d(2560, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (874): AdaptiveAvgPool2d(output_size=1)
#   (875): Dropout(p=0.5, inplace=False)
#   (876): AdaptiveAvgPool2d(output_size=1)
#   (877): AdaptiveMaxPool2d(output_size=1)
#   (878): AdaptiveAvgPool2d(output_size=1)
#   (879): Linear(in_features=5120, out_features=320, bias=False)
#   (880): ReLU(inplace=True)
#   (881): Linear(in_features=320, out_features=5120, bias=False)
#   (882): Sigmoid()
#   (883): Mish()
#   (884): Flatten()
#   (885): BatchNorm1d(5120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (886): Dropout(p=0.5, inplace=False)
#   (887): Linear(in_features=5120, out_features=512, bias=True)
#   (888): Mish()
#   (889): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (890): Dropout(p=0.5, inplace=False)
#   (891): Linear(in_features=512, out_features=11, bias=True)
#   (892): AdaptiveAvgPool2d(output_size=1)
#   (893): AdaptiveMaxPool2d(output_size=1)
#   (894): AdaptiveAvgPool2d(output_size=1)
#   (895): Linear(in_features=5120, out_features=320, bias=False)
#   (896): ReLU(inplace=True)
#   (897): Linear(in_features=320, out_features=5120, bias=False)
#   (898): Sigmoid()
#   (899): Mish()
#   (900): Flatten()
#   (901): BatchNorm1d(5120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (902): Dropout(p=0.5, inplace=False)
#   (903): Linear(in_features=5120, out_features=512, bias=True)
#   (904): Mish()
#   (905): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (906): Dropout(p=0.5, inplace=False)
#   (907): Linear(in_features=512, out_features=7, bias=True)
# ), Sequential(
#   (0): AdaptiveAvgPool2d(output_size=1)
#   (1): AdaptiveMaxPool2d(output_size=1)
#   (2): AdaptiveAvgPool2d(output_size=1)
#   (3): Linear(in_features=5156, out_features=322, bias=False)
#   (4): ReLU(inplace=True)
#   (5): Linear(in_features=322, out_features=5156, bias=False)
#   (6): Sigmoid()
#   (7): Mish()
#   (8): Flatten()
#   (9): BatchNorm1d(5156, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): Dropout(p=0.5, inplace=False)
#   (11): Linear(in_features=5156, out_features=512, bias=True)
#   (12): Mish()
#   (13): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (14): Dropout(p=0.5, inplace=False)
#   (15): Linear(in_features=512, out_features=168, bias=True)
# )], add_time=True, silent=False)

# %%
# !pip install torchsummary
from torchsummary import summary

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
summary(model, (1, 128, 128))
# Out:
# Collecting torchsummary
#   Downloading https://files.pythonhosted.org/packages/7d/18/1474d06f721b86e6a9b9d7392ad68bed711a02f3b61ac43f13c719db50a6/torchsummary-1.5.1-py3-none-any.whl
# Installing collected packages: torchsummary
# Successfully installed torchsummary-1.5.1
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#          ZeroPad2d-1          [-1, 1, 129, 129]               0
# Conv2dStaticSamePadding-2           [-1, 64, 64, 64]             576
#        BatchNorm2d-3           [-1, 64, 64, 64]             128
#          ZeroPad2d-4           [-1, 64, 66, 66]               0
# Conv2dStaticSamePadding-5           [-1, 64, 64, 64]             576
#        BatchNorm2d-6           [-1, 64, 64, 64]             128
# MemoryEfficientSwish-7           [-1, 64, 64, 64]               0
#           Identity-8             [-1, 64, 1, 1]               0
# Conv2dStaticSamePadding-9             [-1, 16, 1, 1]           1,040
# MemoryEfficientSwish-10             [-1, 16, 1, 1]               0
#          Identity-11             [-1, 16, 1, 1]               0
# Conv2dStaticSamePadding-12             [-1, 64, 1, 1]           1,088
#          Identity-13           [-1, 64, 64, 64]               0
# Conv2dStaticSamePadding-14           [-1, 32, 64, 64]           2,048
#       BatchNorm2d-15           [-1, 32, 64, 64]              64
#       MBConvBlock-16           [-1, 32, 64, 64]               0
#         ZeroPad2d-17           [-1, 32, 66, 66]               0
# Conv2dStaticSamePadding-18           [-1, 32, 64, 64]             288
#       BatchNorm2d-19           [-1, 32, 64, 64]              64
# MemoryEfficientSwish-20           [-1, 32, 64, 64]               0
#          Identity-21             [-1, 32, 1, 1]               0
# Conv2dStaticSamePadding
[-1, 224, 8, 8]               0
# Conv2dStaticSamePadding-482           [-1, 1344, 8, 8]         301,056
#      BatchNorm2d-483           [-1, 1344, 8, 8]           2,688
# MemoryEfficientSwish-484           [-1, 1344, 8, 8]               0
#        ZeroPad2d-485         [-1, 1344, 12, 12]               0
# Conv2dStaticSamePadding-486           [-1, 1344, 8, 8]          33,600
#      BatchNorm2d-487           [-1, 1344, 8, 8]           2,688
# MemoryEfficientSwish-488           [-1, 1344, 8, 8]               0
#         Identity-489           [-1, 1344, 1, 1]               0
# Conv2dStaticSamePadding-490             [-1, 56, 1, 1]          75,320
# MemoryEfficientSwish-491             [-1, 56, 1, 1]               0
#         Identity-492             [-1, 56, 1, 1]               0
# Conv2dStaticSamePadding-493           [-1, 1344, 1, 1]          76,608
#         Identity-494           [-1, 1344, 8, 8]               0
# Conv2dStaticSamePadding-495            [-1, 224, 8, 8]         301,056
#      BatchNorm2d-496            [-1, 224, 8, 8]             448
#      MBConvBlock-497            [-1, 224, 8, 8]               0
#         Identity-498            [-1, 224, 8, 8]               0
# Conv2dStaticSamePadding-499           [-1, 1344, 8, 8]         301,056
#      BatchNorm2d-500           [-1, 1344, 8, 8]           2,688
# MemoryEfficientSwish-501           [-1, 1344, 8, 8]               0
#        ZeroPad2d-502         [-1, 1344, 12, 12]               0
# Conv2dStaticSamePadding-503           [-1, 1344, 8, 8]          33,600
#      BatchNorm2d-504           [-1, 1344, 8, 8]           2,688
# MemoryEfficientSwish-505           [-1, 1344, 8, 8]               0
#         Identity-506           [-1, 1344, 1, 1]               0
# Conv2dStaticSamePadding-507             [-1, 56, 1, 1]          75,320
# MemoryEfficientSwish-508             [-1, 56, 1, 1]               0
#         Identity-509             [-1, 56, 1, 1]               0
# Conv2dStaticSamePadding-510           [-1, 1344, 1, 1]          76,608
#         Identity-511           [-1, 1344, 8, 8]               0
# Conv2dStaticSamePadding-512            [-1, 224, 8, 8]         301,056
#      BatchNorm2d-513            [-1, 224, 8, 8]             448
#      MBConvBlock-514            [-1, 224, 8, 8]               0
#         Identity-515            [-1, 224, 8, 8]               0
# Conv2dStaticSamePadding-516           [-1, 1344, 8, 8]         301,056
#      BatchNorm2d-517           [-1, 1344, 8, 8]           2,688
# MemoryEfficientSwish-518           [-1, 1344, 8, 8]               0
#        ZeroPad2d-519         [-1, 1344, 12, 12]               0
# Conv2dStaticSamePadding-520           [-1, 1344, 8, 8]          33,600
#      BatchNorm2d-521           [-1, 1344, 8, 8]           2,688
# MemoryEfficientSwish-522           [-1, 1344, 8, 8]               0
#         Identity-523           [-1, 1344, 1, 1]               0
# Conv2dStaticSamePadding-524             [-1, 56, 1, 1]          75,320
# MemoryEfficientSwish-525             [-1, 56, 1, 1]               0
#         Identity-526             [-1, 56, 1, 1]               0
# Conv2dStaticSamePadding-527           [-1, 1344, 1, 1]          76,608
#         Identity-528           [-1, 1344, 8, 8]               0
# Conv2dStaticSamePadding-529            [-1, 224, 8, 8]         301,056
#      BatchNorm2d-530            [-1, 224, 8, 8]             448
#      MBConvBlock-531            [-1, 224, 8, 8]               0
#         Identity-532            [-1, 224, 8, 8]               0
# Conv2dStaticSamePadding-533           [-1, 1344, 8, 8]         301,056
#      BatchNorm2d-534           [-1, 1344, 8, 8]           2,688
# MemoryEfficientSwish-535           [-1, 1344, 8, 8]               0
#        ZeroPad2d-536         [-1, 1344, 12, 12]               0
# Conv2dStaticSamePadding-537           [-1, 1344, 8, 8]          33,600
#      BatchNorm2d-538           [-1, 1344, 8, 8]           2,688
# MemoryEfficientSwish-539           [-1, 1344, 8, 8]               0
#         Identity-540           [-1, 1344, 1, 1]               0
# Conv2dStaticSamePadding-541             [-1, 56, 1, 1]          75,320
# MemoryEfficientSwish-542             [-1, 56, 1, 1]               0
#         Identity-543             [-1, 56, 1, 1]               0
# Conv2dStaticSamePadding-544           [-1, 1344, 1, 1]          76,608
#         Identity-545           [-1, 1344, 8, 8]               0
# Conv2dStaticSamePadding-546            [-1, 224, 8, 8]         301,056
#      BatchNorm2d-547            [-1, 224, 8, 8]             448
#      MBConvBlock-548            [-1, 224, 8, 8]               0
#         Identity-549            [-1, 224, 8, 8]               0
# Conv2dStaticSamePadding-550           [-1, 1344, 8, 8]         301,056
#      BatchNorm2d-551           [-1, 1344, 8, 8]           2,688
# MemoryEfficientSwish-552           [-1, 1344, 8, 8]               0
#        ZeroPad2d-553         [-1, 1344, 12, 12]               0
# Conv2dStaticSamePadding-554           [-1, 1344, 8, 8]          33,600
#      BatchNorm2d-555           [-1, 1344, 8, 8]           2,688
# MemoryEfficientSwish-556           [-1, 1344, 8, 8]               0
#         Identity-557           [-1, 1344, 1, 1]               0
# Conv2dStaticSamePadding-558             [-1, 56, 1, 1]          75,320
# MemoryEfficientSwish-559             [-1, 56, 1, 1]               0
#         Identity-560             [-1, 56, 1, 1]               0
# Conv2dStaticSamePadding-561           [-1, 1344, 1, 1]          76,608
#         Identity-562           [-1, 1344, 8, 8]               0
# Conv2dStaticSamePadding-563            [-1, 224, 8, 8]         301,056
#      BatchNorm2d-564            [-1, 224, 8, 8]             448
#      MBConvBlock-565            [-1, 224, 8, 8]               0
#         Identity-566            [-1, 224, 8, 8]               0
# Conv2dStaticSamePadding-567           [-1, 1344, 8, 8]         301,056
#      BatchNorm2d-568           [-1, 1344, 8, 8]           2,688
# MemoryEfficientSwish-569           [-1, 1344, 8, 8]               0
#        ZeroPad2d-570         [-1, 1344, 12, 12]               0
# Conv2dStaticSamePadding-571           [-1, 1344, 8, 8]          33,600
#      BatchNorm2d-572           [-1, 1344, 8, 8]           2,688
# MemoryEfficientSwish-573           [-1, 1344, 8, 8]               0
#         Identity-574           [-1, 1344, 1, 1]               0
# Conv2dStaticSamePadding-575             [-1, 56, 1, 1]          75,320
# MemoryEfficientSwish-576             [-1, 56, 1, 1]               0
#         Identity-577             [-1, 56, 1, 1]               0
# Conv2dStaticSamePadding-578           [-1, 1344, 1, 1]          76,608
#         Identity-579           [-1, 1344, 8, 8]               0
# Conv2dStaticSamePadding-580            [-1, 224, 8, 8]         301,056
#      BatchNorm2d-581            [-1, 224, 8, 8]             448
#      MBConvBlock-582            [-1, 224, 8, 8]               0
#         Identity-583            [-1, 224, 8, 8]               0
# Conv2dStaticSamePadding-584           [-1, 1344, 8, 8]         301,056
#      BatchNorm2d-585           [-1, 1344, 8, 8]           2,688
# MemoryEfficientSwish-586           [-1, 1344, 8, 8]               0
#        ZeroPad2d-587         [-1, 1344, 12, 12]               0
# Conv2dStaticSamePadding-588           [-1, 1344, 8, 8]          33,600
#      BatchNorm2d-589           [-1, 1344, 8, 8]           2,688
# MemoryEfficientSwish-590           [-1, 1344, 8, 8]               0
#         Identity-591           [-1, 1344, 1, 1]               0
# Conv2dStaticSamePadding-592             [-1, 56, 1, 1]          75,320
# MemoryEfficientSwish-593             [-1, 56, 1, 1]               0
#         Identity-594             [-1, 56, 1, 1]               0
# Conv2dStaticSamePadding-595           [-1, 1344, 1, 1]          76,608
#         Identity-596           [-1, 1344, 8, 8]               0
# Conv2dStaticSamePadding-597            [-1, 224, 8, 8]         301,056
#      BatchNorm2d-598            [-1, 224, 8, 8]             448
#      MBConvBlock-599            [-1, 224, 8, 8]               0
#         Identity-600            [-1, 224, 8, 8]               0
# Conv2dStaticSamePadding-601           [-1, 1344, 8, 8]         301,056
#      BatchNorm2d-602           [-1, 1344, 8, 8]           2,688
# MemoryEfficientSwish-603           [-1, 1344, 8, 8]               0
#        ZeroPad2d-604         [-1, 1344, 12, 12]               0
# Conv2dStaticSamePadding-605           [-1, 1344, 8, 8]          33,600
#      BatchNorm2d-606           [-1, 1344, 8, 8]           2,688
# MemoryEfficientSwish-607           [-1, 1344, 8, 8]               0
#         Identity-608           [-1, 1344, 1, 1]               0
# Conv2dStaticSamePadding-609             [-1, 56, 1, 1]          75,320
# MemoryEfficientSwish-610             [-1, 56, 1, 1]               0
#         Identity-611             [-1, 56, 1, 1]               0
# Conv2dStaticSamePadding-612           [-1, 1344, 1, 1]          76,608
#         Identity-613           [-1, 1344, 8, 8]               0
# Conv2dStaticSamePadding-614            [-1, 224, 8, 8]         301,056
#      BatchNorm2d-615            [-1, 224, 8, 8]             448
#      MBConvBlock-616            [-1, 224, 8, 8]               0
#         Identity-617            [-1, 224, 8, 8]               0
# Conv2dStaticSamePadding-618           [-1, 1344, 8, 8]         301,056
#      BatchNorm2d-619           [-1, 1344, 8, 8]           2,688
# MemoryEfficientSwish-620           [-1, 1344, 8, 8]               0
#        ZeroPad2d-621         [-1, 1344, 12, 12]               0
# Conv2dStaticSamePadding-622           [-1, 1344, 8, 8]          33,600
#      BatchNorm2d-623           [-1, 1344, 8, 8]           2,688
# MemoryEfficientSwish-624           [-1, 1344, 8, 8]               0
#         Identity-625           [-1, 1344, 1, 1]               0
# Conv2dStaticSamePadding-626             [-1, 56, 1, 1]          75,320
# MemoryEfficientSwish-627             [-1, 56, 1, 1]               0
#         Identity-628             [-1, 56, 1, 1]               0
# Conv2dStaticSamePadding-629           [-1, 1344, 1, 1]          76,608
#         Identity-630           [-1, 1344, 8, 8]               0
# Conv2dStaticSamePadding-631            [-1, 224, 8, 8]         301,056
#      BatchNorm2d-632            [-1, 224, 8, 8]             448
#      MBConvBlock-633            [-1, 224, 8, 8]               0
#         Identity-634            [-1, 224, 8, 8]               0
# Conv2dStaticSamePadding-635           [-1, 1344, 8, 8]         301,056
#      BatchNorm2d-636           [-1, 1344, 8, 8]           2,688
# MemoryEfficientSwish-637           [-1, 1344, 8, 8]               0
#        ZeroPad2d-638         [-1, 1344, 11, 11]               0
# Conv2dStaticSamePadding-639           [-1, 1344, 4, 4]          33,600
#      BatchNorm2d-640           [-1, 1344, 4, 4]           2,688
# MemoryEfficientSwish-641           [-1, 1344, 4, 4]               0
#         Identity-642           [-1, 1344, 1, 1]               0
# Conv2dStaticSamePadding-643             [-1, 56, 1, 1]          75,320
# MemoryEfficientSwish-644             [-1, 56, 1, 1]               0
#         Identity-645             [-1, 56, 1, 1]               0
# Conv2dStaticSamePadding-646           [-1, 1344, 1, 1]          76,608
#         Identity-647           [-1, 1344, 4, 4]               0
# Conv2dStaticSamePadding-648            [-1, 384, 4, 4]         516,096
#      BatchNorm2d-649            [-1, 384, 4, 4]             768
#      MBConvBlock-650            [-1, 384, 4, 4]               0
#         Identity-651            [-1, 384, 4, 4]               0
# Conv2dStaticSamePadding-652           [-1, 2304, 4, 4]         884,736
#      BatchNorm2d-653           [-1, 2304, 4, 4]           4,608
# MemoryEfficientSwish-654           [-1, 2304, 4, 4]               0
#        ZeroPad2d-655           [-1, 2304, 8, 8]               0
# Conv2dStaticSamePadding-656           [-1, 2304, 4, 4]          57,600
#      BatchNorm2d-657           [-1, 2304, 4, 4]           4,608
# MemoryEfficientSwish-658           [-1, 2304, 4, 4]               0
#         Identity-659           [-1, 2304, 1, 1]               0
# Conv2dStaticSamePadding-660             [-1, 96, 1, 1]         221,280
# MemoryEfficientSwish-661             [-1, 96, 1, 1]               0
#         Identity-662             [-1, 96, 1, 1]               0
# Conv2dStaticSamePadding-663           [-1, 2304, 1, 1]         223,488
#         Identity-664           [-1, 2304, 4, 4]               0
# Conv2dStaticSamePadding-665            [-1, 384, 4, 4]         884,736
#      BatchNorm2d-666            [-1, 384, 4, 4]             768
#      MBConvBlock-667            [-1, 384, 4, 4]               0
#         Identity-668            [-1, 384, 4, 4]               0
# Conv2dStaticSamePadding-669           [-1, 2304, 4, 4]         884,736
#      BatchNorm2d-670           [-1, 2304, 4, 4]           4,608
# MemoryEfficientSwish-671           [-1, 2304, 4, 4]               0
#        ZeroPad2d-672           [-1, 2304, 8, 8]               0
# Conv2dStaticSamePadding-673           [-1, 2304, 4, 4]          57,600
#      BatchNorm2d-674           [-1, 2304, 4, 4]           4,608
# MemoryEfficientSwish-675           [-1, 2304, 4, 4]               0
#         Identity-676           [-1, 2304, 1, 1]               0
# Conv2dStaticSamePadding-677             [-1, 96, 1, 1]         221,280
# MemoryEfficientSwish-678             [-1, 96, 1, 1]               0
#         Identity-679             [-1, 96, 1, 1]               0
# Conv2dStaticSamePadding-680           [-1, 2304, 1, 1]         223,488
#         Identity-681           [-1, 2304, 4, 4]               0
# Conv2dStaticSamePadding-682            [-1, 384, 4, 4]         884,736
#      BatchNorm2d-683            [-1, 384, 4, 4]             768
#      MBConvBlock-684            [-1, 384, 4, 4]               0
#         Identity-685            [-1, 384, 4, 4]               0
# Conv2dStaticSamePadding-686           [-1, 2304, 4, 4]         884,736
#      BatchNorm2d-687           [-1, 2304, 4, 4]           4,608
# MemoryEfficientSwish-688           [-1, 2304, 4, 4]               0
#        ZeroPad2d-689           [-1, 2304, 8, 8]               0
# Conv2dStaticSamePadding-690           [-1, 2304, 4, 4]          57,600
#      BatchNorm2d-691           [-1, 2304, 4, 4]           4,608
# MemoryEfficientSwish-692           [-1, 2304, 4, 4]               0
#         Identity-693           [-1, 2304, 1, 1]               0
# Conv2dStaticSamePadding-694             [-1, 96, 1, 1]         221,280
# MemoryEfficientSwish-695             [-1, 96, 1, 1]               0
#         Identity-696             [-1, 96, 1, 1]               0
# Conv2dStaticSamePadding-697           [-1, 2304, 1, 1]         223,488
#         Identity-698           [-1, 2304, 4, 4]               0
# Conv2dStaticSamePadding-699            [-1, 384, 4, 4]         884,736
#      BatchNorm2d-700            [-1, 384, 4, 4]             768
#      MBConvBlock-701            [-1, 384, 4, 4]               0
#         Identity-702            [-1, 384, 4, 4]               0
# Conv2dStaticSamePadding-703           [-1, 2304, 4, 4]         884,736
#      BatchNorm2d-704           [-1, 2304, 4, 4]           4,608
# MemoryEfficientSwish-705           [-1, 2304, 4, 4]               0
#        ZeroPad2d-706           [-1, 2304, 8, 8]               0
# Conv2dStaticSamePadding-707           [-1, 2304, 4, 4]          57,600
#      BatchNorm2d-708           [-1, 2304, 4, 4]           4,608
# MemoryEfficientSwish-709           [-1, 2304, 4, 4]               0
#         Identity-710           [-1, 2304, 1, 1]               0
# Conv2dStaticSamePadding-711             [-1, 96, 1, 1]         221,280
# MemoryEfficientSwish-712             [-1, 96, 1, 1]               0
# ...
# Conv2dStaticSamePadding-750            [-1, 384, 4, 4]         884,736
#      BatchNorm2d-751            [-1, 384, 4, 4]             768
#      MBConvBlock-752            [-1, 384, 4, 4]               0
#         Identity-753            [-1, 384, 4, 4]               0
# Conv2dStaticSamePadding-754           [-1, 2304, 4, 4]         884,736
#      BatchNorm2d-755           [-1, 2304, 4, 4]           4,608
# MemoryEfficientSwish-756           [-1, 2304, 4, 4]               0
#        ZeroPad2d-757           [-1, 2304, 8, 8]               0
# Conv2dStaticSamePadding-758           [-1, 2304, 4, 4]          57,600
#      BatchNorm2d-759           [-1, 2304, 4, 4]           4,608
# MemoryEfficientSwish-760           [-1, 2304, 4, 4]               0
#         Identity-761           [-1, 2304, 1, 1]               0
# Conv2dStaticSamePadding-762             [-1, 96, 1, 1]         221,280
# MemoryEfficientSwish-763             [-1, 96, 1, 1]               0
#         Identity-764             [-1, 96, 1, 1]               0
# Conv2dStaticSamePadding-765           [-1, 2304, 1, 1]         223,488
#         Identity-766           [-1, 2304, 4, 4]               0
# Conv2dStaticSamePadding-767            [-1, 384, 4, 4]         884,736
#      BatchNorm2d-768            [-1, 384, 4, 4]             768
#      MBConvBlock-769            [-1, 384, 4, 4]               0
#         Identity-770            [-1, 384, 4, 4]               0
# Conv2dStaticSamePadding-771           [-1, 2304, 4, 4]         884,736
#      BatchNorm2d-772           [-1, 2304, 4, 4]           4,608
# MemoryEfficientSwish-773           [-1, 2304, 4, 4]               0
#        ZeroPad2d-774           [-1, 2304, 8, 8]               0
# Conv2dStaticSamePadding-775           [-1, 2304, 4, 4]          57,600
#      BatchNorm2d-776           [-1, 2304, 4, 4]           4,608
# MemoryEfficientSwish-777           [-1, 2304, 4, 4]               0
#         Identity-778           [-1, 2304, 1, 1]               0
# Conv2dStaticSamePadding-779             [-1, 96, 1, 1]         221,280
# MemoryEfficientSwish-780             [-1, 96, 1, 1]               0
#         Identity-781             [-1, 96, 1, 1]               0
# Conv2dStaticSamePadding-782           [-1, 2304, 1, 1]         223,488
#         Identity-783           [-1, 2304, 4, 4]               0
# Conv2dStaticSamePadding-784            [-1, 384, 4, 4]         884,736
#      BatchNorm2d-785            [-1, 384, 4, 4]             768
#      MBConvBlock-786            [-1, 384, 4, 4]               0
#         Identity-787            [-1, 384, 4, 4]               0
# Conv2dStaticSamePadding-788           [-1, 2304, 4, 4]         884,736
#      BatchNorm2d-789           [-1, 2304, 4, 4]           4,608
# MemoryEfficientSwish-790           [-1, 2304, 4, 4]               0
#        ZeroPad2d-791           [-1, 2304, 8, 8]               0
# Conv2dStaticSamePadding-792           [-1, 2304, 4, 4]          57,600
#      BatchNorm2d-793           [-1, 2304, 4, 4]           4,608
# MemoryEfficientSwish-794           [-1, 2304, 4, 4]               0
#         Identity-795           [-1, 2304, 1, 1]               0
# Conv2dStaticSamePadding-796             [-1, 96, 1, 1]         221,280
# MemoryEfficientSwish-797             [-1, 96, 1, 1]               0
#         Identity-798             [-1, 96, 1, 1]               0
# Conv2dStaticSamePadding-799           [-1, 2304, 1, 1]         223,488
#         Identity-800           [-1, 2304, 4, 4]               0
# Conv2dStaticSamePadding-801            [-1, 384, 4, 4]         884,736
#      BatchNorm2d-802            [-1, 384, 4, 4]             768
#      MBConvBlock-803            [-1, 384, 4, 4]               0
#         Identity-804            [-1, 384, 4, 4]               0
# Conv2dStaticSamePadding-805           [-1, 2304, 4, 4]         884,736
#      BatchNorm2d-806           [-1, 2304, 4, 4]           4,608
# MemoryEfficientSwish-807           [-1, 2304, 4, 4]               0
#        ZeroPad2d-808           [-1, 2304, 8, 8]               0
# Conv2dStaticSamePadding-809           [-1, 2304, 4, 4]          57,600
#      BatchNorm2d-810           [-1, 2304, 4, 4]           4,608
# MemoryEfficientSwish-811           [-1, 2304, 4, 4]               0
#         Identity-812           [-1, 2304, 1, 1]               0
# Conv2dStaticSamePadding-813             [-1, 96, 1, 1]         221,280
# MemoryEfficientSwish-814             [-1, 96, 1, 1]               0
#         Identity-815             [-1, 96, 1, 1]               0
# Conv2dStaticSamePadding-816           [-1, 2304, 1, 1]         223,488
#         Identity-817           [-1, 2304, 4, 4]               0
# Conv2dStaticSamePadding-818            [-1, 384, 4, 4]         884,736
#      BatchNorm2d-819            [-1, 384, 4, 4]             768
#      MBConvBlock-820            [-1, 384, 4, 4]               0
#         Identity-821            [-1, 384, 4, 4]               0
# Conv2dStaticSamePadding-822           [-1, 2304, 4, 4]         884,736
#      BatchNorm2d-823           [-1, 2304, 4, 4]           4,608
# MemoryEfficientSwish-824           [-1, 2304, 4, 4]               0
#        ZeroPad2d-825           [-1, 2304, 8, 8]               0
# Conv2dStaticSamePadding-826           [-1, 2304, 4, 4]          57,600
#      BatchNorm2d-827           [-1, 2304, 4, 4]           4,608
# MemoryEfficientSwish-828           [-1, 2304, 4, 4]               0
#         Identity-829           [-1, 2304, 1, 1]               0
# Conv2dStaticSamePadding-830             [-1, 96, 1, 1]         221,280
# MemoryEfficientSwish-831             [-1, 96, 1, 1]               0
#         Identity-832             [-1, 96, 1, 1]               0
# Conv2dStaticSamePadding-833           [-1, 2304, 1, 1]         223,488
#         Identity-834           [-1, 2304, 4, 4]               0
# Conv2dStaticSamePadding-835            [-1, 384, 4, 4]         884,736
#      BatchNorm2d-836            [-1, 384, 4, 4]             768
#      MBConvBlock-837            [-1, 384, 4, 4]               0
#         Identity-838            [-1, 384, 4, 4]               0
# Conv2dStaticSamePadding-839           [-1, 2304, 4, 4]         884,736
#      BatchNorm2d-840           [-1, 2304, 4, 4]           4,608
# MemoryEfficientSwish-841           [-1, 2304, 4, 4]               0
#        ZeroPad2d-842           [-1, 2304, 8, 8]               0
# Conv2dStaticSamePadding-843           [-1, 2304, 4, 4]          57,600
#      BatchNorm2d-844           [-1, 2304, 4, 4]           4,608
# MemoryEfficientSwish-845           [-1, 2304, 4, 4]               0
#         Identity-846           [-1, 2304, 1, 1]               0
# Conv2dStaticSamePadding-847             [-1, 96, 1, 1]         221,280
# MemoryEfficientSwish-848             [-1, 96, 1, 1]               0
#         Identity-849             [-1, 96, 1, 1]               0
# Conv2dStaticSamePadding-850           [-1, 2304, 1, 1]         223,488
#         Identity-851           [-1, 2304, 4, 4]               0
# Conv2dStaticSamePadding-852            [-1, 384, 4, 4]         884,736
#      BatchNorm2d-853            [-1, 384, 4, 4]             768
#      MBConvBlock-854            [-1, 384, 4, 4]               0
#         Identity-855            [-1, 384, 4, 4]               0
# Conv2dStaticSamePadding-856           [-1, 2304, 4, 4]         884,736
#      BatchNorm2d-857           [-1, 2304, 4, 4]           4,608
# MemoryEfficientSwish-858           [-1, 2304, 4, 4]               0
#        ZeroPad2d-859           [-1, 2304, 6, 6]               0
# Conv2dStaticSamePadding-860           [-1, 2304, 4, 4]          20,736
#      BatchNorm2d-861           [-1, 2304, 4, 4]           4,608
# MemoryEfficientSwish-862           [-1, 2304, 4, 4]               0
#         Identity-863           [-1, 2304, 1, 1]               0
# Conv2dStaticSamePadding-864             [-1, 96, 1, 1]         221,280
# MemoryEfficientSwish-865             [-1, 96, 1, 1]               0
#         Identity-866             [-1, 96, 1, 1]               0
# Conv2dStaticSamePadding-867           [-1, 2304, 1, 1]         223,488
#         Identity-868           [-1, 2304, 4, 4]               0
# Conv2dStaticSamePadding-869            [-1, 640, 4, 4]       1,474,560
#      BatchNorm2d-870            [-1, 640, 4, 4]           1,280
#      MBConvBlock-871            [-1, 640, 4, 4]               0
#         Identity-872            [-1, 640, 4, 4]               0
# Conv2dStaticSamePadding-873           [-1, 3840, 4, 4]       2,457,600
#      BatchNorm2d-874           [-1, 3840, 4, 4]           7,680
# MemoryEfficientSwish-875           [-1, 3840, 4, 4]               0
#        ZeroPad2d-876           [-1, 3840, 6, 6]               0
# Conv2dStaticSamePadding-877           [-1, 3840, 4, 4]          34,560
#      BatchNorm2d-878           [-1, 3840, 4, 4]           7,680
# MemoryEfficientSwish-879           [-1, 3840, 4, 4]               0
#         Identity-880           [-1, 3840, 1, 1]               0
# Conv2dStaticSamePadding-881            [-1, 160, 1, 1]         614,560
# MemoryEfficientSwish-882            [-1, 160, 1, 1]               0
#         Identity-883            [-1, 160, 1, 1]               0
# Conv2dStaticSamePadding-884           [-1, 3840, 1, 1]         618,240
#         Identity-885           [-1, 3840, 4, 4]               0
# Conv2dStaticSamePadding-886            [-1, 640, 4, 4]       2,457,600
#      BatchNorm2d-887            [-1, 640, 4, 4]           1,280
#      MBConvBlock-888            [-1, 640, 4, 4]               0
#         Identity-889            [-1, 640, 4, 4]               0
# Conv2dStaticSamePadding-890           [-1, 3840, 4, 4]       2,457,600
#      BatchNorm2d-891           [-1, 3840, 4, 4]           7,680
# MemoryEfficientSwish-892           [-1, 3840, 4, 4]               0
#        ZeroPad2d-893           [-1, 3840, 6, 6]               0
# Conv2dStaticSamePadding-894           [-1, 3840, 4, 4]          34,560
#      BatchNorm2d-895           [-1, 3840, 4, 4]           7,680
# MemoryEfficientSwish-896           [-1, 3840, 4, 4]               0
#         Identity-897           [-1, 3840, 1, 1]               0
# Conv2dStaticSamePadding-898            [-1, 160, 1, 1]         614,560
# MemoryEfficientSwish-899            [-1, 160, 1, 1]               0
#         Identity-900            [-1, 160, 1, 1]               0
# Conv2dStaticSamePadding-901           [-1, 3840, 1, 1]         618,240
#         Identity-902           [-1, 3840, 4, 4]               0
# Conv2dStaticSamePadding-903            [-1, 640, 4, 4]       2,457,600
#      BatchNorm2d-904            [-1, 640, 4, 4]           1,280
#      MBConvBlock-905            [-1, 640, 4, 4]               0
#         Identity-906            [-1, 640, 4, 4]               0
# Conv2dStaticSamePadding-907           [-1, 3840, 4, 4]       2,457,600
#      BatchNorm2d-908           [-1, 3840, 4, 4]           7,680
# MemoryEfficientSwish-909           [-1, 3840, 4, 4]               0
#        ZeroPad2d-910           [-1, 3840, 6, 6]               0
# Conv2dStaticSamePadding-911           [-1, 3840, 4, 4]          34,560
#      BatchNorm2d-912           [-1, 3840, 4, 4]           7,680
# MemoryEfficientSwish-913           [-1, 3840, 4, 4]               0
#         Identity-914           [-1, 3840, 1, 1]               0
# Conv2dStaticSamePadding-915            [-1, 160, 1, 1]         614,560
# MemoryEfficientSwish-916            [-1, 160, 1, 1]               0
#         Identity-917            [-1, 160, 1, 1]               0
# Conv2dStaticSamePadding-918           [-1, 3840, 1, 1]         618,240
#         Identity-919           [-1, 3840, 4, 4]               0
# Conv2dStaticSamePadding-920            [-1, 640, 4, 4]       2,457,600
#      BatchNorm2d-921            [-1, 640, 4, 4]           1,280
#      MBConvBlock-922            [-1, 640, 4, 4]               0
#         Identity-923            [-1, 640, 4, 4]               0
# Conv2dStaticSamePadding-924           [-1, 2560, 4, 4]       1,638,400
#      BatchNorm2d-925           [-1, 2560, 4, 4]           5,120
# AdaptiveAvgPool2d-926           [-1, 2560, 1, 1]               0
#          Dropout-927           [-1, 2560, 1, 1]               0
# AdaptiveMaxPool2d-928           [-1, 2560, 1, 1]               0
# AdaptiveAvgPool2d-929           [-1, 2560, 1, 1]               0
# AdaptiveConcatPool2d-930           [-1, 5120, 1, 1]               0
# AdaptiveAvgPool2d-931           [-1, 5120, 1, 1]               0
#           Linear-932                  [-1, 320]       1,638,400
#             ReLU-933                  [-1, 320]               0
#           Linear-934                 [-1, 5120]       1,638,400
#          Sigmoid-935                 [-1, 5120]               0
#          SELayer-936           [-1, 5120, 1, 1]               0
#             Mish-937           [-1, 5120, 1, 1]               0
#          Flatten-938                 [-1, 5120]               0
#      BatchNorm1d-939                 [-1, 5120]          10,240
#          Dropout-940                 [-1, 5120]               0
#           Linear-941                  [-1, 512]       2,621,952
#             Mish-942                  [-1, 512]               0
#      BatchNorm1d-943                  [-1, 512]           1,024
#          Dropout-944                  [-1, 512]               0
#           Linear-945                   [-1, 11]           5,643
#             Head-946                   [-1, 11]               0
# AdaptiveMaxPool2d-947           [-1, 2560, 1, 1]               0
# AdaptiveAvgPool2d-948           [-1, 2560, 1, 1]               0
# AdaptiveConcatPool2d-949           [-1, 5120, 1, 1]               0
# AdaptiveAvgPool2d-950           [-1, 5120, 1, 1]               0
#           Linear-951                  [-1, 320]       1,638,400
#             ReLU-952                  [-1, 320]               0
#           Linear-953                 [-1, 5120]       1,638,400
#          Sigmoid-954                 [-1, 5120]               0
#          SELayer-955           [-1, 5120, 1, 1]               0
#             Mish-956           [-1, 5120, 1, 1]               0
#          Flatten-957                 [-1, 5120]               0
#      BatchNorm1d-958                 [-1, 5120]          10,240
#          Dropout-959                 [-1, 5120]               0
#           Linear-960                  [-1, 512]       2,621,952
#             Mish-961                  [-1, 512]               0
#      BatchNorm1d-962                  [-1, 512]           1,024
#          Dropout-963                  [-1, 512]               0
#           Linear-964                    [-1, 7]           3,591
#             Head-965                    [-1, 7]               0
# AdaptiveMaxPool2d-966           [-1, 2578, 1, 1]               0
# AdaptiveAvgPool2d-967           [-1, 2578, 1, 1]               0
# AdaptiveConcatPool2d-968           [-1, 5156, 1, 1]               0
# AdaptiveAvgPool2d-969           [-1, 5156, 1, 1]               0
#           Linear-970                  [-1, 322]       1,660,232
#             ReLU-971                  [-1, 322]               0
#           Linear-972                 [-1, 5156]       1,660,232
#          Sigmoid-973                 [-1, 5156]               0
#          SELayer-974           [-1, 5156, 1, 1]               0
#             Mish-975           [-1, 5156, 1, 1]               0
#          Flatten-976                 [-1, 5156]               0
#      BatchNorm1d-977                 [-1, 5156]          10,312
#          Dropout-978                 [-1, 5156]               0
#           Linear-979                  [-1, 512]       2,640,384
#             Mish-980                  [-1, 512]               0
#      BatchNorm1d-981                  [-1, 512]           1,024
#          Dropout-982                  [-1, 512]               0
#           Linear-983                  [-1, 168]          86,184
#             Head-984                  [-1, 168]               0
# ================================================================
# Total params: 81,673,442
# Trainable params: 81,673,442
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.06
# Forward/backward pass size (MB): 427.83
# Params size (MB): 311.56
# Estimated Total Size (MB): 739.46
# ----------------------------------------------------------------

# %%
summary(Head(2560, 168).to(device), (2560, 1, 1))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#  AdaptiveMaxPool2d-1           [-1, 2560, 1, 1]               0
#  AdaptiveAvgPool2d-2           [-1, 2560, 1, 1]               0
# AdaptiveConcatPool2d-3           [-1, 5120, 1, 1]               0
#  AdaptiveAvgPool2d-4           [-1, 5120, 1, 1]               0
#             Linear-5                  [-1, 320]       1,638,400
#               ReLU-6                  [-1, 320]               0
#             Linear-7                 [-1, 5120]       1,638,400
#            Sigmoid-8                 [-1, 5120]               0
#            SELayer-9           [-1, 5120, 1, 1]               0
#              Mish-10           [-1, 5120, 1, 1]               0
#           Flatten-11                 [-1, 5120]               0
#       BatchNorm1d-12                 [-1, 5120]          10,240
#           Dropout-13                 [-1, 5120]               0
#            Linear-14                  [-1, 512]       2,621,952
#              Mish-15                  [-1, 512]               0
#       BatchNorm1d-16                  [-1, 512]           1,024
#           Dropout-17                  [-1, 512]               0
#            Linear-18                  [-1, 168]          86,184
# ================================================================
# Total params: 5,996,200
# Trainable params: 5,996,200
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.41
# Params size (MB): 22.87
# Estimated Total Size (MB): 23.30
# ----------------------------------------------------------------

# %%
import gc

gc.collect()
torch.cuda.empty_cache()

# %%
learn.fit_one_cycle(1, max_lr=slice(0.2e-2,1e-2), wd=[1e-3,0.1e-1], pct_start=0.0, 
    div_factor=100, callbacks = [logger, SaveModelCallback(learn,monitor='metric_tot',
    mode='max',name=f'model_{fold}'),MixUpCallback(learn)])
#metrics: Metric_grapheme, Metric_vowel, Metric_consonant, Metric_tot (competition metric)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>metric_idx</th>
#       <th>metric_idx</th>
#       <th>metric_idx</th>
#       <th>metric_tot</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.895096</td>
#       <td>0.116803</td>
#       <td>0.944558</td>
#       <td>0.981558</td>
#       <td>0.977815</td>
#       <td>0.962122</td>
#       <td>2:51:27</td>
#     </tr>
#   </tbody>
# </table>
